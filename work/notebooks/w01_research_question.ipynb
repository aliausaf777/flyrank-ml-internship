# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aliausaf777/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Chosen Lane
# **Refresh / Content Opportunity Scoring**
#
# I selected the **Refresh / Content Opportunity Scoring** lane because it focuses on helping content teams identify which pages should be reviewed first based on measurable search and content performance signals. Rather than simply training a machine learning model, this project aims to support better decision-making by ranking pages according to their potential need for content updates or improvement.
#
# This lane allows me to apply machine learning techniques to a practical business problem while learning how to analyze search performance, identify content opportunities, and generate evidence-based recommendations. It also aligns with my goal of improving my data analysis and machine learning skills through real-world applications.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# **Research Question:** Which content pages should be prioritized for review and refresh based on their search and content performance signals?
#
# **Decision:** Determine which pages should be reviewed first.
#
# **Unit of Analysis:** One content page.
#
# **Output:** A ranked list of content pages with refresh opportunity scores and supporting reason codes.
#
# **Action:** The SEO or content team can review the highest-ranked pages first and decide whether to refresh, expand, optimize, monitor, or keep the content unchanged.
#
# **Cost of a Wrong Recommendation:** If the ranking is incorrect, important pages may be overlooked while low-priority pages receive unnecessary attention. This can waste time and resources and reduce the effectiveness of content optimization efforts.
#
# **Why Machine Learning Helps:** Machine learning can analyze multiple search and content performance signals simultaneously, making it easier to identify patterns and prioritize pages more effectively than relying only on manual review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os

print("Searching for CSV files...\n")

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# Searching for CSV files...
#
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
